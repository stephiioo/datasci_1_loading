# %% [markdown]
# <a href="https://colab.research.google.com/github/stephiioo/datasci_1_loading/blob/main/data_(week_1_homework).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CSV File 1

# %%
import pandas as pd

# %%
csv1 = pd.read_csv('/data/Covid Data.csv')
csv1.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a137f8a621c0> in <cell line: 1>()
# ----> 1 csv1 = pd.read_csv('/data/Covid Data.csv')
#       2 csv1.head(10)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
csv2 = pd.read_csv('data/tested.csv')
csv2.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
csv3 = pd.read_csv('data/heart.csv')
csv3.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
xlsx1 = pd.read_excel('/data/Acoustic_Extinguisher_Fire_Dataset.xlsx')
xlsx1.head(10)
# Out:
#    SIZE      FUEL  DISTANCE  DESIBEL  AIRFLOW  FREQUENCY  STATUS
# 0     1  gasoline        10       96      0.0         75       0
# 1     1  gasoline        10       96      0.0         72       1
# 2     1  gasoline        10       96      2.6         70       1
# 3     1  gasoline        10       96      3.2         68       1
# 4     1  gasoline        10      109      4.5         67       1
# 5     1  gasoline        10      109      7.8         66       1
# 6     1  gasoline        10      103      9.7         65       1
# 7     1  gasoline        10       95     12.0         60       1
# 8     1  gasoline        10      102     13.3         55       1
# 9     1  gasoline        10       93     15.4         52       1

# %%
xlsx2 = pd.read_excel('/data/Pistachio_16_Features_Dataset.xlsx')
xlsx2.head(10)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  63391   1568.405    390.3396    236.7461        0.7951  284.0984    0.8665
# 1  68358   1942.187    410.8594    234.7525        0.8207  295.0188    0.8765
# 2  73589   1246.538    452.3630    220.5547        0.8731  306.0987    0.9172
# 3  71106   1445.261    429.5291    216.0765        0.8643  300.8903    0.9589
# 4  80087   1251.524    469.3783    220.9344        0.8823  319.3273    0.9657
# 5  52268   1154.150    383.8558    197.5020        0.8575  257.9723    0.8563
# 6  71693   1463.932    388.2366    252.8200        0.7589  302.1297    0.9156
# 7  62240   1898.450    385.7238    218.1349        0.8247  281.5074    0.8947
# 8  64319   2011.291    435.9127    213.7594        0.8715  286.1704    0.8633
# 9  78115   1238.623    492.3300    204.9987        0.9092  315.3714    0.9616
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# ...

# %%
xlsx3 = pd.read_excel('/data/Spotify_data.xlsx')
xlsx3.head(10)
# Out:
#      Age  Gender spotify_usage_period  \
# 0  20-35  Female    More than 2 years
# 1  12-20    Male    More than 2 years
# 2  35-60  Others   6 months to 1 year
# 3  20-35  Female    1 year to 2 years
# 4  20-35  Female    1 year to 2 years
# 5  20-35    Male    More than 2 years
# 6  20-35  Female    1 year to 2 years
# 7  20-35  Female   Less than 6 months
# 8  20-35  Female   Less than 6 months
# 9  20-35  Female    More than 2 years
#
#                          spotify_listening_device spotify_subscription_plan  \
# 0              Smart speakers or voice assistants       Free (ad-supported)
# 1                              Computer or laptop       Free (ad-supported)
# 2              Smart speakers or voice assistants       Free (ad-supported)
# 3  Smartphone, Smart speakers or voice assistants       Free (ad-supported)
# 4                                      Smartphone       Free (ad-supported)
# 5                                      Smartphone       Free (ad-supported)
# ...

# %%
json1 = pd.read_json('/data/Intent.json')
json1.head(10)
# Out:
#                                              intents
# 0  {'intent': 'Greeting', 'text': ['Hi', 'Hi ther...
# 1  {'intent': 'GreetingResponse', 'text': ['My us...
# 2  {'intent': 'CourtesyGreeting', 'text': ['How a...
# 3  {'intent': 'CourtesyGreetingResponse', 'text':...
# 4  {'intent': 'CurrentHumanQuery', 'text': ['What...
# 5  {'intent': 'NameQuery', 'text': ['What is your...
# 6  {'intent': 'RealNameQuery', 'text': ['What is ...
# 7  {'intent': 'TimeQuery', 'text': ['What is the ...
# 8  {'intent': 'Thanks', 'text': ['OK thank you', ...
# 9  {'intent': 'NotTalking2U', 'text': ['I am not ...

# %%
json2 = pd.read_json('/data/recipes.json')
json2.head(10)
# Out:
#                                                  Url  \
# 0   https://www.chefkoch.de/rezepte/185441079701305/
# 1  https://www.chefkoch.de/rezepte/2718181424631245/
# 2    https://www.chefkoch.de/rezepte/46341015661368/
# 3    https://www.chefkoch.de/rezepte/51051018014178/
# 4  https://www.chefkoch.de/rezepte/1555771262860408/
# 5   https://www.chefkoch.de/rezepte/318661113606205/
# 6   https://www.chefkoch.de/rezepte/307991111110164/
# 7   https://www.chefkoch.de/rezepte/800291183649658/
# 8   https://www.chefkoch.de/rezepte/295691108953224/
# 9    https://www.chefkoch.de/rezepte/44381015086527/
#
#                                         Instructions  \
# 0  Die Eier hart kochen. Dann pellen und mit eine...
# 1  Vorab folgende Bemerkung: Alle Mengen sind Cir...
# 2  Die Kirschen abtropfen lassen, dabei den Saft ...
# 3  Den Spargel säubern, die holzigen Enden abschn...
# 4  Kohlrabi schälen und klein würfeln. Mit der Br...
# 5  Aus dem Mehl, der Butter, dem Ei und etwas Sal...
# ...

# %%
json3 = pd.read_json('/data/quotes.json')
json3.head(10)
# Out:
#                                                Quote             Author  \
# 0  Don't cry because it's over, smile because it ...          Dr. Seuss
# 1  Don't cry because it's over, smile because it ...          Dr. Seuss
# 2  I'm selfish, impatient and a little insecure. ...     Marilyn Monroe
# 3  I'm selfish, impatient and a little insecure. ...     Marilyn Monroe
# 4  I'm selfish, impatient and a little insecure. ...     Marilyn Monroe
# 5       Be yourself; everyone else is already taken.        Oscar Wilde
# 6  Two things are infinite: the universe and huma...    Albert Einstein
# 7  Two things are infinite: the universe and huma...    Albert Einstein
# 8  Two things are infinite: the universe and huma...    Albert Einstein
# 9  Be who you are and say what you feel, because ...  Bernard M. Baruch
#
#                                                 Tags  Popularity     Category
# 0  [attributed-no-source, cry, crying, experience...    0.155666         life
# ...
